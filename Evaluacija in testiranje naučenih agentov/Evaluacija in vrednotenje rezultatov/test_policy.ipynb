# %% [markdown]
# ## Imports

# %%
import os

# %%
import gym
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import ParameterGrid

# %%
import tensorflow as tf
import torch

# %%
from spinup.utils.test_policy import load_policy_and_env, run_policy

# %%
import sys, os
sys.path.append('/home/anej/repos/diplomska-code/learning')

from utils.algorithm_logging import AlgorithmLogger
from utils.constants import PlottingConstants

# %% [markdown]
# ## Train the agent and evaluate it

# %%
env_name = 'CartPole-v2'

# model_logdir = '/home/anej/repos/spinningup/data/cartpole_mountain/cartpole_mountain_s938274'
model_logdir = '/home/anej/repos/spinningup/data/cartpole_obstacle/cartpole_obstacle_s251632'

env, get_action = load_policy_and_env(model_logdir, env_name, False, 'last', True)

for _ in range(10):
    algorithm_logger = AlgorithmLogger(
        max_no_of_episodes=200,
        max_time_steps_per_episode=250,
        observation_size=7 if env_name == 'CartPole-v3' else 4,
        start=-5,
        goal=1.5)

    run_policy(env, get_action, 0, 1, False, algorithm_logger=algorithm_logger)

    for what in PlottingConstants.SINGLE_EPISODE_STATISTICS:
        algorithm_logger.plot_summary(what)    

#     algorithm_logger.plot_single_episodes_summary(PlottingConstants.HEIGHT)
# Out:
# Loading from /home/anej/repos/spinningup/data/cartpole_obstacle/cartpole_obstacle_s251632/pyt_save/model.pt.
#
#
# Logging data to /tmp/experiments/1594216678/progress.txt
# Episode 0 	 EpRet -0.072 	 EpLen 250
# -------------------------------------
# |    AverageEpRet |          -0.072 |
# |        StdEpRet |               0 |
# |        MaxEpRet |          -0.072 |
# |        MinEpRet |          -0.072 |
# |           EpLen |             250 |
# -------------------------------------
# Logging data to /tmp/experiments/1594216680/progress.txt
# Episode 0 	 EpRet -0.096 	 EpLen 250
# -------------------------------------
# |    AverageEpRet |          -0.096 |
# |        StdEpRet |               0 |
# |        MaxEpRet |          -0.096 |
# |        MinEpRet |          -0.096 |
# |           EpLen |             250 |
# -------------------------------------
# Logging data to /tmp/experiments/1594216682/progress.txt
# Episode 0 	 EpRet -0.134 	 EpLen 250
# ...
